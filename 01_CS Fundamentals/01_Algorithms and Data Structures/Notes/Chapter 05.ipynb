# %% [markdown]
# # Chapter 05: Stacks, Queues, and Deques

# %% [markdown]
# ## 5.1. Stacks
#
# Stacks are LIFO (last-in, first-out) containers.
# * Inserting element: PUSH
# * Removing element: POP

# %% [markdown]
# ### 5.1.1. The Stack ADT
#
# * ADTs
#     * push(e): Insert element *e* at the top of the stack.
#     * pop(): Remove the top element
#     * top(): Return the top element
#     * size(): Return the number of elements
#     * empty(): Return true if the stack is empty

# %% [markdown]
# ### 5.1.2. The STL Stack
#
# * Can be used by `#include <stack>`

# %% [markdown]
# ### 5.1.3. A C++ Stack Interface

# %% [markdown]
# ### 5.1.4. A Simply Array-Based Stack Implementation

# %% [markdown]
# ### 5.1.5. Implementing a Stack with Generic Linked List
